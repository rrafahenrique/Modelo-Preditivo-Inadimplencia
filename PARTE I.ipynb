# %% [markdown]
# <div style="
#     background-color: #3D5A73;
#     color: white;
#     width: 1000px;
#     height: 120px;                 /* define altura fixa */
#     margin: 20px auto;
#     border-radius: 15px;
#     display: flex;                 /* ativa flexbox */
#     align-items: center;           /* centraliza vertical */
#     justify-content: center;       /* centraliza horizontal */
# ">
#     <h1 style="margin: 0;">PARTE I - MODELO PREDITIVO</h1>
# </div>

# %% [markdown]
# # Introdução
# Imagine que você trabalhe em uma empresa de consultoria especializada em soluções de dados e inteligência de crédito. Atuando com grandes instituições financeiras, desenvolvendo modelos preditivos, sistema de apoio à decisão e estratégias baseadas em dados. Você foi alocado em um projeto que envolve o acompanhamento de transações financeiras realizadas por clientes ao longo do tempo.
#
# # Objetivo Principal
# Desenvolver um **modelo preditivo** capaz de estimar a probabilidade de inadimplência de cobranças mensais feitas aos clientes. A **inadimplência** é definida da seguinte forma:
# > Um pagamento é considerado inadimplente se for realizado com **5 dias ou mais de atraso** em relação à data de vencimento.
#
# As previsões devem conter apenas a probabilidade de inadimplência (valores entre 0 e 1).
#
# # Estrutura do Projeto
# 1. **Configurações Iniciais**: Import das bibliotecas que serão utilizadas e visualização do dataset;
# 2. **Tratamento dos Dados Ausente**: Identificação e imputação de dados ausentes;
# 3. **Análise Exploratória dos Dados**: Visualização de padrões, tendências por meio de gráficos de barras para análise quantitativa do dataset;
# 4. **Visualização da Variável Target**: Construção de gráficos de barras e interpretação dos resultados para identificar padrões e distribuição da variável alvo;
# 5. **Conclusão**

# %% [markdown]
# <div style="
#     background-color: #3D5A73;
#     color: white;
#     width: 700px;
#     height: 120px;                 /* define altura fixa */
#     margin: 20px auto;
#     border-radius: 15px;
#     display: flex;                 /* ativa flexbox */
#     align-items: center;           /* centraliza vertical */
#     justify-content: center;       /* centraliza horizontal */
# ">
#     <h1 style="margin: 0;">1. Configurações Iniciais</h1>
# </div>

# %% [markdown]
# ## 1.1 Importando Bibliotecas e Dataset

# %%
# Import das bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils.analysis_utils as func

#Configuração padrão do gráfico
plt.style.use('default')

import warnings
warnings.filterwarnings('ignore')

# %%
# custom palette
customPalette = ["#008F8C" ,"#015958", "#023535", "#4C5958", "#BFBFBF", "#D92525"]
sns.set_palette(customPalette)
sns.palplot(customPalette)

# %%
# Lendo os arquivos .csv
base_cadastral = pd.read_csv("data/base_cadastral.csv", sep = ";")
base_pagamentos = pd.read_csv('data/base_pagamentos_desenvolvimento.csv', sep = ';')
base_info = pd.read_csv('data/base_info.csv', sep = ';')

# %%
# Merge de base_pagamentos com base_info (mesma chave composta)
df_merge = pd.merge(
    base_pagamentos,
    base_info,
    on = ["ID_CLIENTE", "SAFRA_REF"],
    how = "left" 
)

# Merge de df_merge com base_cadastral por ID_CLIENTE
df = pd.merge(
    df_merge,
    base_cadastral,
    on = "ID_CLIENTE",
    how = "left"
)

display(df)
# Out:
#                 ID_CLIENTE SAFRA_REF DATA_EMISSAO_DOCUMENTO DATA_PAGAMENTO  \
# 0      1661240395903230676   2018-08             2018-08-17     2018-09-06
# 1      1661240395903230676   2018-08             2018-08-19     2018-09-11
# 2      1661240395903230676   2018-08             2018-08-26     2018-09-18
# 3      1661240395903230676   2018-08             2018-08-30     2018-10-11
# 4      1661240395903230676   2018-08             2018-08-31     2018-09-20
# ...                    ...       ...                    ...            ...
# 77409  2951563549197799278   2021-06             2021-06-30     2021-07-16
# 77410  5220206408301580591   2021-06             2021-06-30     2021-08-16
# 77411  5860276371789140450   2021-06             2021-06-30     2021-07-16
# 77412  2814790209436551216   2021-06             2021-06-30     2021-07-16
# 77413  8343941262792249232   2021-06             2021-06-30     2021-08-16
#
#       DATA_VENCIMENTO  VALOR_A_PAGAR  TAXA  RENDA_MES_ANTERIOR  \
# 0          2018-09-06       35516.41  6.99                 NaN
# 1          2018-09-10       17758.21  6.99                 NaN
# 2          2018-09-17       17431.96  6.99                 NaN
# 3          2018-10-05        1341.00  6.99                 NaN
# 4          2018-09-20       21309.85  6.99                 NaN
# ...               ...            ...   ...                 ...
# 77409      2021-07-16       89980.00  5.99            280343.0
# 77410      2021-08-16       42239.00  5.99            235315.0
# 77411      2021-07-16       20921.50  5.99            100006.0
# 77412      2021-07-16       90231.05  6.99                 NaN
# 77413      2021-08-16       20736.51  4.99             97599.0
#
#        NO_FUNCIONARIOS DATA_CADASTRO DDD FLAG_PF SEGMENTO_INDUSTRIAL  \
# 0                  NaN    2013-08-22  99     NaN            Serviços
# 1                  NaN    2013-08-22  99     NaN            Serviços
# 2                  NaN    2013-08-22  99     NaN            Serviços
# 3                  NaN    2013-08-22  99     NaN            Serviços
# 4                  NaN    2013-08-22  99     NaN            Serviços
# ...                ...           ...  ..     ...                 ...
# 77409            161.0    2000-08-15  11     NaN            Comércio
# 77410             87.0    2021-04-08  19     NaN           Indústria
# 77411              NaN    2011-02-15  91     NaN            Serviços
# 77412              NaN    2021-05-13  (1     NaN            Serviços
# 77413              NaN    2019-05-28  11     NaN           Indústria
#
#       DOMINIO_EMAIL    PORTE CEP_2_DIG
# 0             YAHOO  PEQUENO        65
# 1             YAHOO  PEQUENO        65
# 2             YAHOO  PEQUENO        65
# 3             YAHOO  PEQUENO        65
# 4             YAHOO  PEQUENO        65
# ...             ...      ...       ...
# 77409           AOL  PEQUENO        13
# 77410         GMAIL   GRANDE        25
# 77411       HOTMAIL   GRANDE        67
# 77412         YAHOO    MEDIO        14
# 77413       HOTMAIL   GRANDE        31
#
# [77414 rows x 16 columns]

# %% [markdown]
# ## 1.2 Sumário do Dataset
# - `ID_CLIENTE`: Identificador único do cliente.
# - `SAFRA_REF`: Mês de referência da amostra​
# - `DATA_EMISSAO_DOCUMENTO`*: Data da emissão da nota de crédito​
# - `DATA_PAGAMENTO`: Data em que o cliente realizou o pagamento da nota
# - `DATA_VENCIMENTO`: Data limite para pagamento do empréstimo​
# - `VALOR_A_PAGAR`: Valor da nota de crédito​
# - `TAXA`: Taxa de juros cobrada no empréstimo​
# - `RENDA_MES_ANTERIOR`: Renda ou faturamento declarado pelo cliente no fim do mês anterior​
# - `NO_FUNCIONARIOS`: Número de funcionários reportado pelo cliente no fim do mês anterior
# - `DATA_CADASTRO`: Data da realização do cadastro no sistema.
# - `DDD`: Número do DDD do telefone do cliente.
# - `FLAG_PF`: Indica se o cliente é uma pessoa física (`X`) ou jurídica (`NaN`).
# - `SEGMENTO_INDUSTRIAL`: Indica a qual segmento da indústria pertence o cliente.
# - `DOMINIO_EMAIL`: Indica o domínio(ou provedor) do email utilizado para o cadastro.
# - `PORTE`: Indica o porte (tamanho) da empresa.
# - `CEP_2_DIG`: Indica os dois primeiros números do CEP do endereço cadastrado.

# %%
func.df_summary_report(df)
# Out:
# <style type="text/css">
# #T_10e3c th {
#   background-color: #0c2845;
#   color: white;
#   text-align: center;
#   font-size: 13px;
# }
# #T_10e3c_row0_col0, #T_10e3c_row1_col0, #T_10e3c_row2_col0, #T_10e3c_row3_col0, #T_10e3c_row4_col0, #T_10e3c_row5_col0, #T_10e3c_row6_col0, #T_10e3c_row7_col0, #T_10e3c_row8_col0, #T_10e3c_row9_col0, #T_10e3c_row10_col0, #T_10e3c_row11_col0, #T_10e3c_row12_col0, #T_10e3c_row13_col0, #T_10e3c_row14_col0, #T_10e3c_row15_col0 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #012030;
#   font-weight: bold;
#   color: #FFFFFF;
# }
# #T_10e3c_row0_col1, #T_10e3c_row0_col2, #T_10e3c_row0_col5, #T_10e3c_row1_col1, #T_10e3c_row1_col2, #T_10e3c_row1_col5, #T_10e3c_row2_col1, #T_10e3c_row2_col2, #T_10e3c_row2_col5, #T_10e3c_row3_col1, #T_10e3c_row3_col2, #T_10e3c_row3_col5, #T_10e3c_row4_col1, #T_10e3c_row4_col2, #T_10e3c_row4_col5, #T_10e3c_row5_col1, #T_10e3c_row5_col2, #T_10e3c_row5_col5, #T_10e3c_row6_col1, #T_10e3c_row6_col2, #T_10e3c_row6_col5, #T_10e3c_row7_col1, #T_10e3c_row7_col2, #T_10e3c_row7_col5, #T_10e3c_row8_col1, #T_10e3c_row8_col2, #T_10e3c_row8_col5, #T_10e3c_row9_col1, #T_10e3c_row9_col2, #T_10e3c_row9_col5, #T_10e3c_row10_col1, #T_10e3c_row10_col2, #T_10e3c_row10_col5, #T_10e3c_row11_col1, #T_10e3c_row11_col2, #T_10e3c_row11_col5, #T_10e3c_row12_col1, #T_10e3c_row12_col2, #T_10e3c_row12_col5, #T_10e3c_row13_col1, #T_10e3c_row13_col2, #T_10e3c_row13_col5, #T_10e3c_row14_col1, #T_10e3c_row14_col2, #T_10e3c_row14_col5, #T_10e3c_row15_col1, #T_10e3c_row15_col2, #T_10e3c_row15_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
# }
# #T_10e3c_row0_col3, #T_10e3c_row1_col3, #T_10e3c_row2_col3, #T_10e3c_row3_col3, #T_10e3c_row4_col3, #T_10e3c_row6_col3, #T_10e3c_row9_col3, #T_10e3c_row15_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
# }
# #T_10e3c_row0_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eceff2;
#   color: #000000;
# }
# #T_10e3c_row0_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #e8edef;
#   color: #000000;
# }
# #T_10e3c_row0_col7, #T_10e3c_row5_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #ebeff1;
#   color: #000000;
# }
# #T_10e3c_row0_col8, #T_10e3c_row1_col8, #T_10e3c_row2_col8, #T_10e3c_row3_col8, #T_10e3c_row4_col8, #T_10e3c_row6_col8, #T_10e3c_row9_col8, #T_10e3c_row15_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #f2f0f0;
#   color: #000000;
# }
# #T_10e3c_row0_col9, #T_10e3c_row1_col4, #T_10e3c_row1_col7, #T_10e3c_row2_col6, #T_10e3c_row5_col9, #T_10e3c_row6_col4, #T_10e3c_row6_col7, #T_10e3c_row6_col9, #T_10e3c_row7_col6, #T_10e3c_row7_col9, #T_10e3c_row8_col4, #T_10e3c_row8_col7, #T_10e3c_row8_col9, #T_10e3c_row10_col4, #T_10e3c_row10_col7, #T_10e3c_row11_col4, #T_10e3c_row11_col7, #T_10e3c_row12_col4, #T_10e3c_row12_col7, #T_10e3c_row13_col4, #T_10e3c_row13_col7, #T_10e3c_row14_col4, #T_10e3c_row14_col7, #T_10e3c_row15_col4, #T_10e3c_row15_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eff1f3;
#   color: #000000;
# }
# #T_10e3c_row1_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #dfe7eb;
#   color: #000000;
# }
# #T_10e3c_row1_col9 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #5792aa;
#   color: #f1f1f1;
# }
# #T_10e3c_row2_col4, #T_10e3c_row3_col4, #T_10e3c_row4_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #edeff2;
#   color: #000000;
# }
# #T_10e3c_row2_col7, #T_10e3c_row3_col7, #T_10e3c_row4_col7, #T_10e3c_row11_col9 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eceff1;
#   color: #000000;
# }
# #T_10e3c_row2_col9, #T_10e3c_row3_col9, #T_10e3c_row4_col9 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #16698b;
#   color: #f1f1f1;
# }
# #T_10e3c_row3_col6, #T_10e3c_row9_col4, #T_10e3c_row11_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eef0f2;
#   color: #000000;
# }
# #T_10e3c_row4_col6, #T_10e3c_row9_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #edf0f2;
#   color: #000000;
# }
# #T_10e3c_row5_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #BD2A2E 1.5%, transparent 1.5%);
# }
# #T_10e3c_row5_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_10e3c_row5_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #2f7897;
#   color: #f1f1f1;
# }
# #T_10e3c_row5_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_10e3c_row6_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #377e9b;
#   color: #f1f1f1;
# }
# #T_10e3c_row7_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #BD2A2E 7.9%, transparent 7.9%);
# }
# #T_10e3c_row7_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #b9d1e2;
#   color: #000000;
# }
# #T_10e3c_row7_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #bdd2db;
#   color: #000000;
# }
# #T_10e3c_row7_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eee1e1;
#   color: #000000;
# }
# #T_10e3c_row8_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #BD2A2E 9.8%, transparent 9.8%);
# }
# #T_10e3c_row8_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #e4eaed;
#   color: #000000;
# }
# #T_10e3c_row8_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eddddd;
#   color: #000000;
# }
# #T_10e3c_row9_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #71a2b7;
#   color: #f1f1f1;
# }
# #T_10e3c_row9_col9, #T_10e3c_row12_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #13678a;
#   color: #f1f1f1;
# }
# #T_10e3c_row10_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #BD2A2E 9.6%, transparent 9.6%);
# }
# #T_10e3c_row10_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #b4ccd7;
#   color: #000000;
# }
# #T_10e3c_row10_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #edddde;
#   color: #000000;
# }
# #T_10e3c_row10_col9 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;

# %% [markdown]
# <div style="
#     background-color: #3D5A73;
#     color: white;
#     width: 700px;
#     height: 120px;                 /* define altura fixa */
#     margin: 20px auto;
#     border-radius: 15px;
#     display: flex;                 /* ativa flexbox */
#     align-items: center;           /* centraliza vertical */
#     justify-content: center;       /* centraliza horizontal */
# ">
#     <h1 style="margin: 0;">2. Tratamento dos Dados Ausentes</h1>
# </div>

# %% [markdown]
# As colunas `VALOR_A_PAGAR`, `RENDA_MES_ANTERIOR`, `NO_FUNCIONARIOS`, `DDD`, `FLAG_PF`, `SEGMENTO_INDUSTRIAL`, `DOMINIO_EMAIL` e `PORTE` possuem valores ausente, é possível observar que a coluna `FLAG_PF` é a que apresenta maior deficit de dados faltantes.
#
# Vamos primeiro analisar a coluna `FLAG_PF`, existe uma discrepância muito grande da coluna `FLAG_PF`, uma informação que temos é que esta coluna está classificada da seguinte maneira:
# - Se o cliente é uma Pessoa Física no dataset está definido como (`X`)
# - Se o cliente é uma Pessoa Jurídica esta cadastro como (`NaN`).

# %%
# Altera o Nan presente na tabela para Jurídico para facilitar o entendimento
df['FLAG_PF'] = df['FLAG_PF'].fillna('Juridico')

# Altera o X presente na tabela para Pessoa Física para facilitar o entendimento
df['FLAG_PF'] = df['FLAG_PF'].replace('X', 'Pessoa_Fisica')
display(df)
# Out:
#                 ID_CLIENTE SAFRA_REF DATA_EMISSAO_DOCUMENTO DATA_PAGAMENTO  \
# 0      1661240395903230676   2018-08             2018-08-17     2018-09-06
# 1      1661240395903230676   2018-08             2018-08-19     2018-09-11
# 2      1661240395903230676   2018-08             2018-08-26     2018-09-18
# 3      1661240395903230676   2018-08             2018-08-30     2018-10-11
# 4      1661240395903230676   2018-08             2018-08-31     2018-09-20
# ...                    ...       ...                    ...            ...
# 77409  2951563549197799278   2021-06             2021-06-30     2021-07-16
# 77410  5220206408301580591   2021-06             2021-06-30     2021-08-16
# 77411  5860276371789140450   2021-06             2021-06-30     2021-07-16
# 77412  2814790209436551216   2021-06             2021-06-30     2021-07-16
# 77413  8343941262792249232   2021-06             2021-06-30     2021-08-16
#
#       DATA_VENCIMENTO  VALOR_A_PAGAR  TAXA  RENDA_MES_ANTERIOR  \
# 0          2018-09-06       35516.41  6.99                 NaN
# 1          2018-09-10       17758.21  6.99                 NaN
# 2          2018-09-17       17431.96  6.99                 NaN
# 3          2018-10-05        1341.00  6.99                 NaN
# 4          2018-09-20       21309.85  6.99                 NaN
# ...               ...            ...   ...                 ...
# 77409      2021-07-16       89980.00  5.99            280343.0
# 77410      2021-08-16       42239.00  5.99            235315.0
# 77411      2021-07-16       20921.50  5.99            100006.0
# 77412      2021-07-16       90231.05  6.99                 NaN
# 77413      2021-08-16       20736.51  4.99             97599.0
#
#        NO_FUNCIONARIOS DATA_CADASTRO DDD   FLAG_PF SEGMENTO_INDUSTRIAL  \
# 0                  NaN    2013-08-22  99  Juridico            Serviços
# 1                  NaN    2013-08-22  99  Juridico            Serviços
# 2                  NaN    2013-08-22  99  Juridico            Serviços
# 3                  NaN    2013-08-22  99  Juridico            Serviços
# 4                  NaN    2013-08-22  99  Juridico            Serviços
# ...                ...           ...  ..       ...                 ...
# 77409            161.0    2000-08-15  11  Juridico            Comércio
# 77410             87.0    2021-04-08  19  Juridico           Indústria
# 77411              NaN    2011-02-15  91  Juridico            Serviços
# 77412              NaN    2021-05-13  (1  Juridico            Serviços
# 77413              NaN    2019-05-28  11  Juridico           Indústria
#
#       DOMINIO_EMAIL    PORTE CEP_2_DIG
# 0             YAHOO  PEQUENO        65
# 1             YAHOO  PEQUENO        65
# 2             YAHOO  PEQUENO        65
# 3             YAHOO  PEQUENO        65
# 4             YAHOO  PEQUENO        65
# ...             ...      ...       ...
# 77409           AOL  PEQUENO        13
# 77410         GMAIL   GRANDE        25
# 77411       HOTMAIL   GRANDE        67
# 77412         YAHOO    MEDIO        14
# 77413       HOTMAIL   GRANDE        31
#
# [77414 rows x 16 columns]

# %%
func.plot_missing_values(df)

# %% [markdown]
# Agora vamos analisar a quantidade de daddos vazios da Coluna `NO_FUNCIONARIOS`, pelo gráfico temos 9,8% de dados ausentes. Vamos olhar mais de perto as insformações desta feature e planejar uma forma de tratar esse problema.
#
# A primeira coisa que podemos fazer é usar o método `describe()` que gera um resumo estatístico rápido de um DataFrame ou Série, fornecendo métricas como contagem, média, desvio padrão, mínimo, máximo e quartis para colunas numéricas, e contagem, valores únicos, moda (mais frequente) e frequência para colunas categóricas, ajudando a entender a distribuição e as características dos dados.

# %%
func.df_describe_report(df)
# Out:
# <style type="text/css">
# #T_09b7c th {
#   background-color: #0c2845;
#   color: white;
#   text-align: center;
#   font-size: 13px;
# }
# #T_09b7c_row0_col0, #T_09b7c_row1_col0, #T_09b7c_row2_col0, #T_09b7c_row3_col0, #T_09b7c_row4_col0, #T_09b7c_row5_col0, #T_09b7c_row6_col0 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #012030;
#   font-weight: bold;
#   color: #FFFFFF;
# }
# #T_09b7c_row0_col1 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #80abbe;
#   color: #f1f1f1;
# }
# #T_09b7c_row0_col2, #T_09b7c_row1_col2, #T_09b7c_row4_col2 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #edf0f2;
#   color: #000000;
# }
# #T_09b7c_row0_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #83adbf;
#   color: #f1f1f1;
# }
# #T_09b7c_row0_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #c9d9e1;
#   color: #000000;
# }
# #T_09b7c_row0_col5, #T_09b7c_row4_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #6c9fb4;
#   color: #f1f1f1;
# }
# #T_09b7c_row1_col1 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #b0c9d5;
#   color: #000000;
# }
# #T_09b7c_row1_col3, #T_09b7c_row2_col1, #T_09b7c_row2_col2, #T_09b7c_row2_col4, #T_09b7c_row2_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eff1f3;
#   color: #000000;
# }
# #T_09b7c_row1_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #d3e0e6;
#   color: #000000;
# }
# #T_09b7c_row1_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #dae4e9;
#   color: #000000;
# }
# #T_09b7c_row2_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #aac6d2;
#   color: #000000;
# }
# #T_09b7c_row3_col1 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #b7ced8;
#   color: #000000;
# }
# #T_09b7c_row3_col2 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eef0f2;
#   color: #000000;
# }
# #T_09b7c_row3_col3, #T_09b7c_row4_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #94b8c8;
#   color: #000000;
# }
# #T_09b7c_row3_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #dee6ea;
#   color: #000000;
# }
# #T_09b7c_row3_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #7aa8bb;
#   color: #f1f1f1;
# }
# #T_09b7c_row4_col1 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #7ca9bc;
#   color: #f1f1f1;
# }
# #T_09b7c_row4_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #d0dde4;
#   color: #000000;
# }
# #T_09b7c_row5_col1 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #4889a3;
#   color: #f1f1f1;
# }
# #T_09b7c_row5_col2 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eceff1;
#   color: #000000;
# }
# #T_09b7c_row5_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #7fabbd;
#   color: #f1f1f1;
# }
# #T_09b7c_row5_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #bbd0da;
#   color: #000000;
# }
# #T_09b7c_row5_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #5e96ae;
#   color: #f1f1f1;
# }
# #T_09b7c_row6_col1, #T_09b7c_row6_col2, #T_09b7c_row6_col3, #T_09b7c_row6_col4, #T_09b7c_row6_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #13678a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09b7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09b7c_level0_col0" class="col_heading level0 col0" >Estatística</th>
#       <th id="T_09b7c_level0_col1" class="col_heading level0 col1" >ID_CLIENTE</th>
#       <th id="T_09b7c_level0_col2" class="col_heading level0 col2" >VALOR_A_PAGAR</th>
#       <th id="T_09b7c_level0_col3" class="col_heading level0 col3" >TAXA</th>
#       <th id="T_09b7c_level0_col4" class="col_heading level0 col4" >RENDA_MES_ANTERIOR</th>
#       <th id="T_09b7c_level0_col5" class="col_heading level0 col5" >NO_FUNCIONARIOS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09b7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09b7c_row0_col0" class="data row0 col0" >Média</td>
#       <td id="T_09b7c_row0_col1" class="data row0 col1" >4662270147931493376.000</td>
#       <td id="T_09b7c_row0_col2" class="data row0 col2" >46590.777</td>
#       <td id="T_09b7c_row0_col3" class="data row0 col3" >6.790</td>
#       <td id="T_09b7c_row0_col4" class="data row0 col4" >291438.084</td>
#       <td id="T_09b7c_row0_col5" class="data row0 col5" >117.693</td>
#     </tr>
#     <tr>
#       <th id="T_09b7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09b7c_row1_col0" class="data row1 col0" >Desvio Padrão</td>
#       <td id="T_09b7c_row1_col1" class="data row1 col1" >2665719403408342528.000</td>
#       <td id="T_09b7c_row1_col2" class="data row1 col2" >46433.930</td>
#       <td id="T_09b7c_row1_col3" class="data row1 col3" >1.798</td>
#       <td id="T_09b7c_row1_col4" class="data row1 col4" >213293.159</td>
#       <td id="T_09b7c_row1_col5" class="data row1 col5" >18.780</td>
#     </tr>
#     <tr>
#       <th id="T_09b7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09b7c_row2_col0" class="data row2 col0" >Valor Mínimo</td>
#       <td id="T_09b7c_row2_col1" class="data row2 col1" >8784237149961904.000</td>
#       <td id="T_09b7c_row2_col2" class="data row2 col2" >0.100</td>
#       <td id="T_09b7c_row2_col3" class="data row2 col3" >4.990</td>
#       <td id="T_09b7c_row2_col4" class="data row2 col4" >105.000</td>
#       <td id="T_09b7c_row2_col5" class="data row2 col5" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_09b7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09b7c_row3_col0" class="data row3 col0" >Primeiro Quartil - Q1</td>
#       <td id="T_09b7c_row3_col1" class="data row3 col1" >2369364892942408192.000</td>
#       <td id="T_09b7c_row3_col2" class="data row3 col2" >18765.362</td>
#       <td id="T_09b7c_row3_col3" class="data row3 col3" >5.990</td>
#       <td id="T_09b7c_row3_col4" class="data row3 col4" >134074.250</td>
#       <td id="T_09b7c_row3_col5" class="data row3 col5" >105.000</td>
#     </tr>
#     <tr>
#       <th id="T_09b7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09b7c_row4_col0" class="data row4 col0" >Segundo Quartil - Q2/Mediana</td>
#       <td id="T_09b7c_row4_col1" class="data row4 col1" >4817816966382229504.000</td>
#       <td id="T_09b7c_row4_col2" class="data row4 col2" >34758.695</td>
#       <td id="T_09b7c_row4_col3" class="data row4 col3" >5.990</td>
#       <td id="T_09b7c_row4_col4" class="data row4 col4" >240502.000</td>
#       <td id="T_09b7c_row4_col5" class="data row4 col5" >118.000</td>
#     </tr>
#     <tr>
#       <th id="T_09b7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_09b7c_row5_col0" class="da

# %%
# Soma o número de empresas que aparecem com 0 funcionários e exclui elas 
df['NO_FUNCIONARIOS'].eq(0).sum()
df = df[df['NO_FUNCIONARIOS'] != 0]

# %% [markdown]
# Agora que eliminamos os valores zerados, podemos estudar a relação entre número de funcionários e o porte da empresa, isso pode nos ajudar a entender qual o perfil de cada instituição.

# %%
# Relação entre número de funcionarios e o tamanho da empresa levando em consideração a mediana
df.groupby('PORTE')['NO_FUNCIONARIOS'].median().to_frame().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_5a6d8_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5a6d8_row1_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_5a6d8_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_5a6d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a6d8_level0_col0" class="col_heading level0 col0" >NO_FUNCIONARIOS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PORTE</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a6d8_level0_row0" class="row_heading level0 row0" >GRANDE</th>
#       <td id="T_5a6d8_row0_col0" class="data row0 col0" >121.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5a6d8_level0_row1" class="row_heading level0 row1" >MEDIO</th>
#       <td id="T_5a6d8_row1_col0" class="data row1 col0" >116.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5a6d8_level0_row2" class="row_heading level0 row2" >PEQUENO</th>
#       <td id="T_5a6d8_row2_col0" class="data row2 col0" >114.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Groupby das colunas  PORTE, SEGMENTO_INDUSTRIAL e NO_FUNCIONARIOS calculando a mediana
df.groupby(['PORTE', 'SEGMENTO_INDUSTRIAL'])['NO_FUNCIONARIOS'].median().to_frame().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_83202_row0_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_83202_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_83202_row2_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_83202_row3_col0, #T_83202_row4_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_83202_row5_col0, #T_83202_row8_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_83202_row6_col0, #T_83202_row7_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_83202">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83202_level0_col0" class="col_heading level0 col0" >NO_FUNCIONARIOS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PORTE</th>
#       <th class="index_name level1" >SEGMENTO_INDUSTRIAL</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83202_level0_row0" class="row_heading level0 row0" rowspan="3">GRANDE</th>
#       <th id="T_83202_level1_row0" class="row_heading level1 row0" >Comércio</th>
#       <td id="T_83202_row0_col0" class="data row0 col0" >119.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level1_row1" class="row_heading level1 row1" >Indústria</th>
#       <td id="T_83202_row1_col0" class="data row1 col0" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level1_row2" class="row_heading level1 row2" >Serviços</th>
#       <td id="T_83202_row2_col0" class="data row2 col0" >122.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level0_row3" class="row_heading level0 row3" rowspan="3">MEDIO</th>
#       <th id="T_83202_level1_row3" class="row_heading level1 row3" >Comércio</th>
#       <td id="T_83202_row3_col0" class="data row3 col0" >117.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level1_row4" class="row_heading level1 row4" >Indústria</th>
#       <td id="T_83202_row4_col0" class="data row4 col0" >117.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level1_row5" class="row_heading level1 row5" >Serviços</th>
#       <td id="T_83202_row5_col0" class="data row5 col0" >115.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level0_row6" class="row_heading level0 row6" rowspan="3">PEQUENO</th>
#       <th id="T_83202_level1_row6" class="row_heading level1 row6" >Comércio</th>
#       <td id="T_83202_row6_col0" class="data row6 col0" >113.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level1_row7" class="row_heading level1 row7" >Indústria</th>
#       <td id="T_83202_row7_col0" class="data row7 col0" >113.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83202_level1_row8" class="row_heading level1 row8" >Serviços</th>
#       <td id="T_83202_row8_col0" class="data row8 col0" >115.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Temos números bem próximos no que diz respeito ao número de funcionários e o segmento industrial em que a empresa atual isso pode influenciar fatores como a escala de produção necessária, o investimento de capital intensivo e a complexidade das operações.
#
# Vamos preencher os dados ausentes com está informação respeitando o porte e o segmento em que a empresa atual.

# %%
# Imputação dos Valores da coluna VALOR_A_PAGAR
mediana_funcionario = df.groupby(['PORTE', 'SEGMENTO_INDUSTRIAL'])['NO_FUNCIONARIOS'].transform('median')
df['NO_FUNCIONARIOS'] = df['NO_FUNCIONARIOS'].fillna(mediana_funcionario)

# %% [markdown]
# Ao reavaliarmos a quantidade de dados ausentes na coluna `NO_FUNCIONARIOS`, observamos que ainda existem valores faltantes no dataset. Isso ocorre porque, ao utilizarmos as variáveis `PORTE` e `SEGMENTO_INDUSTRIAL` para realizar operações de groupby, as linhas que continham valores ausentes nessas colunas não foram consideradas nos agrupamentos, impossibilitando o tratamento completo de todas as observações do conjunto de dados.

# %%
func.plot_missing_values(df)

# %% [markdown]
# Os valores que continuam vazios, irei completar com a média.

# %%
# Calcula a mediana
media = df['NO_FUNCIONARIOS'].mean()

# Preenche os valores ausentes com a mediana
df['NO_FUNCIONARIOS'] = df['NO_FUNCIONARIOS'].fillna(media)

# %% [markdown]
# A coluna `DDD` não será utilizada na análise exploratória nem na construção do modelo de machine learning. Além disso, aproximadamente 10% dos seus registros apresentam valores ausentes. Considerando sua baixa relevância para o problema em estudo e a quantidade significativa de dados faltantes, optou-se pela exclusão dessa variável do dataset.

# %%
# Exclusão da coluna DDD
df = df.drop(['DDD'], axis=1)

# %% [markdown]
# Para as variáveis categóricas `PORTE`, `SEGMENTO_INDUSTRIAL` e `DOMINIO_EMAIL`, adotou-se a imputação pela moda como estratégia para o tratamento de valores ausentes, por se tratar do valor mais representativo dessas distribuições.

# %%
# Calcula a moda (valor mais frequente)
moda_valor = df['PORTE'].mode()[0]
moda_seg = df['SEGMENTO_INDUSTRIAL'].mode()[0]
moda_email = df['DOMINIO_EMAIL'].mode()[0]

# Preenche os valores vazios com a moda
df['PORTE'] = df['PORTE'].fillna(moda_valor)
df['SEGMENTO_INDUSTRIAL'] = df['SEGMENTO_INDUSTRIAL'].fillna(moda_seg)
df['DOMINIO_EMAIL'] = df['DOMINIO_EMAIL'].fillna(moda_email)

# %% [markdown]
# A coluna `VALOR_A_PAGAR` não será imputada de forma isolada. Para aumentar a precisão, os valores ausentes serão estimados a partir de uma análise conjunta com as colunas `PORTE` e `NO_FUNCIONARIOS`, que influenciam diretamente esse valor.
#
# A mesma abordagem será adotada na coluna `RENDA_MES_ANTERIOR`, mas desta vez usarei outras variáveis `PORTE`, `SEGMENTO_INDUSTRIAL` e `TAXA`.

# %%
# Imputação dos Valores da coluna VALOR_A_PAGAR
mediana_valor_pagar = df.groupby(['PORTE', 'NO_FUNCIONARIOS'])['VALOR_A_PAGAR'].transform('median')
df['VALOR_A_PAGAR'] = df['VALOR_A_PAGAR'].fillna(mediana_valor_pagar)

# Imputação dos Valores da coluna RENDA_MES_ANTERIOR
mediana_renda = df.groupby(['PORTE', 'SEGMENTO_INDUSTRIAL', 'TAXA'])['RENDA_MES_ANTERIOR'].transform('median')
df["RENDA_MES_ANTERIOR"] = df["RENDA_MES_ANTERIOR"].fillna(mediana_renda)

# %% [markdown]
# Após o tratamento e a imputação dos valores ausentes, o conjunto de dados encontra-se completo e consistente, estando pronto para a realização da análise exploratória dos dados (Exploratory Data Analysis – EDA).

# %%
# Dataset limpo e sem valores nulos nem vazios.
df.to_parquet('docs/dataset_limpo.parquet', engine='pyarrow')
display(df)
# Out:
#                 ID_CLIENTE SAFRA_REF DATA_EMISSAO_DOCUMENTO DATA_PAGAMENTO  \
# 0      1661240395903230676   2018-08             2018-08-17     2018-09-06
# 1      1661240395903230676   2018-08             2018-08-19     2018-09-11
# 2      1661240395903230676   2018-08             2018-08-26     2018-09-18
# 3      1661240395903230676   2018-08             2018-08-30     2018-10-11
# 4      1661240395903230676   2018-08             2018-08-31     2018-09-20
# ...                    ...       ...                    ...            ...
# 77409  2951563549197799278   2021-06             2021-06-30     2021-07-16
# 77410  5220206408301580591   2021-06             2021-06-30     2021-08-16
# 77411  5860276371789140450   2021-06             2021-06-30     2021-07-16
# 77412  2814790209436551216   2021-06             2021-06-30     2021-07-16
# 77413  8343941262792249232   2021-06             2021-06-30     2021-08-16
#
#       DATA_VENCIMENTO  VALOR_A_PAGAR  TAXA  RENDA_MES_ANTERIOR  \
# 0          2018-09-06       35516.41  6.99            217640.0
# 1          2018-09-10       17758.21  6.99            217640.0
# 2          2018-09-17       17431.96  6.99            217640.0
# 3          2018-10-05        1341.00  6.99            217640.0
# 4          2018-09-20       21309.85  6.99            217640.0
# ...               ...            ...   ...                 ...
# 77409      2021-07-16       89980.00  5.99            280343.0
# 77410      2021-08-16       42239.00  5.99            235315.0
# 77411      2021-07-16       20921.50  5.99            100006.0
# 77412      2021-07-16       90231.05  6.99            234489.0
# 77413      2021-08-16       20736.51  4.99             97599.0
#
#        NO_FUNCIONARIOS DATA_CADASTRO   FLAG_PF SEGMENTO_INDUSTRIAL  \
# 0                115.0    2013-08-22  Juridico            Serviços
# 1                115.0    2013-08-22  Juridico            Serviços
# 2                115.0    2013-08-22  Juridico            Serviços
# 3                115.0    2013-08-22  Juridico            Serviços
# 4                115.0    2013-08-22  Juridico            Serviços
# ...                ...           ...       ...                 ...
# 77409            161.0    2000-08-15  Juridico            Comércio
# 77410             87.0    2021-04-08  Juridico           Indústria
# 77411            122.0    2011-02-15  Juridico            Serviços
# 77412            115.0    2021-05-13  Juridico            Serviços
# 77413            125.0    2019-05-28  Juridico           Indústria
#
#       DOMINIO_EMAIL    PORTE CEP_2_DIG
# 0             YAHOO  PEQUENO        65
# 1             YAHOO  PEQUENO        65
# 2             YAHOO  PEQUENO        65
# 3             YAHOO  PEQUENO        65
# 4             YAHOO  PEQUENO        65
# ...             ...      ...       ...
# 77409           AOL  PEQUENO        13
# 77410         GMAIL   GRANDE        25
# 77411       HOTMAIL   GRANDE        67
# 77412         YAHOO    MEDIO        14
# 77413       HOTMAIL   GRANDE        31
#
# [77267 rows x 15 columns]

# %% [markdown]
# ## 2.1 Tratamento dos Dados de Teste
#
# Uma etapa fundamental em projetos de Machine Learning é garantir que os dados de teste passem pelos mesmos procedimentos de tratamento aplicados aos dados de treino. Isso assegura a consistência dos tipos de dados, formatos e distribuições das variáveis no momento da aplicação do modelo.
#
# Caso esse alinhamento não seja respeitado, podem ocorrer problemas como incompatibilidade de features, erros de execução ou degradação do desempenho do modelo, comprometendo a generalização e a confiabilidade das previsões.
#
# É essencial que o número de colunas (características ou features) seja exatamente o mesmo nas bases de dados de treino e teste.
#
# Isso é um requisito fundamental para a maioria dos algoritmos de machine learning por várias razões:
# 1. **Consistência do Modelo**: O modelo é treinado para aprender um padrão específico com base em um conjunto fixo de entradas (colunas). Para fazer uma previsão, ele espera receber exatamente as mesmas entradas na mesma ordem.
# 2. **Mapeamento de Características**: Se a base de teste tiver uma coluna a menos ou a mais, o algoritmo não saberá como mapear os dados de entrada para os pesos e vieses que aprendeu durante o treinamento.
# 3. **Integridade dos Dados**: Ambas as bases devem representar a mesma estrutura de dados do problema que você está tentando resolver.
#
# O que deve ser igual:
# - **Número de colunas**: Exatamente o mesmo.
# - **Nomes das colunas**: Devem coincidir para garantir que o algoritmo use os dados corretos (ex: a coluna 'idade' na base de treino deve ser a 'idade' na base de teste).
# - **Ordem das colunas**: A maioria das bibliotecas de machine learning requer que a ordem seja idêntica.

# %%
# Lendo o dataset de teste
df_teste = pd.read_csv('data/base_pagamentos_teste.csv', sep = ';')

display(df_teste)
# Out:
#                 ID_CLIENTE SAFRA_REF DATA_EMISSAO_DOCUMENTO DATA_VENCIMENTO  \
# 0      5058298901476893676   2021-07             2021-07-14      2021-08-04
# 1       274692171162531764   2021-07             2021-07-08      2021-08-23
# 2       274692171162531764   2021-07             2021-07-11      2021-08-25
# 3       274692171162531764   2021-07             2021-07-16      2021-08-30
# 4       465309249432033993   2021-07             2021-07-05      2021-07-30
# ...                    ...       ...                    ...             ...
# 12270   705648002974742140   2021-11             2021-11-25      2021-12-13
# 12271  4993499380140734678   2021-11             2021-11-25      2021-12-13
# 12272  4614484019183480654   2021-11             2021-11-26      2028-09-30
# 12273  1299146298565441811   2021-11             2021-11-26      2021-12-13
# 12274  4061297388883391410   2021-11             2021-11-28      2021-12-23
#
#        VALOR_A_PAGAR  TAXA
# 0           11204.75  4.99
# 1           60718.50  5.99
# 2           60718.50  5.99
# 3           62250.00  5.99
# 4           26593.95  6.99
# ...              ...   ...
# 12270       47010.00  6.99
# 12271      122875.35  8.99
# 12272      302200.00  5.99
# 12273      143791.85  5.99
# 12274       23724.10  4.99
#
# [12275 rows x 6 columns]

# %%
func.df_summary_report(df_teste)
# Out:
# <style type="text/css">
# #T_2fb7f th {
#   background-color: #0c2845;
#   color: white;
#   text-align: center;
#   font-size: 13px;
# }
# #T_2fb7f_row0_col0, #T_2fb7f_row1_col0, #T_2fb7f_row2_col0, #T_2fb7f_row3_col0, #T_2fb7f_row4_col0, #T_2fb7f_row5_col0 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #012030;
#   font-weight: bold;
#   color: #FFFFFF;
# }
# #T_2fb7f_row0_col1, #T_2fb7f_row0_col2, #T_2fb7f_row0_col5, #T_2fb7f_row1_col1, #T_2fb7f_row1_col2, #T_2fb7f_row1_col5, #T_2fb7f_row2_col1, #T_2fb7f_row2_col2, #T_2fb7f_row2_col5, #T_2fb7f_row3_col1, #T_2fb7f_row3_col2, #T_2fb7f_row3_col5, #T_2fb7f_row4_col1, #T_2fb7f_row4_col2, #T_2fb7f_row4_col5, #T_2fb7f_row5_col1, #T_2fb7f_row5_col2, #T_2fb7f_row5_col5 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
# }
# #T_2fb7f_row0_col3, #T_2fb7f_row1_col3, #T_2fb7f_row2_col3, #T_2fb7f_row3_col3, #T_2fb7f_row5_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
# }
# #T_2fb7f_row0_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #dde6ed;
#   color: #000000;
# }
# #T_2fb7f_row0_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #e8edef;
#   color: #000000;
# }
# #T_2fb7f_row0_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #dee6ea;
#   color: #000000;
# }
# #T_2fb7f_row0_col8, #T_2fb7f_row1_col8, #T_2fb7f_row2_col8, #T_2fb7f_row3_col8, #T_2fb7f_row5_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #f2f0f0;
#   color: #000000;
# }
# #T_2fb7f_row0_col9, #T_2fb7f_row1_col4, #T_2fb7f_row1_col7, #T_2fb7f_row4_col6, #T_2fb7f_row4_col9, #T_2fb7f_row5_col4, #T_2fb7f_row5_col7, #T_2fb7f_row5_col9 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eff1f3;
#   color: #000000;
# }
# #T_2fb7f_row1_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #5b94ac;
#   color: #f1f1f1;
# }
# #T_2fb7f_row1_col9 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #5590a9;
#   color: #f1f1f1;
# }
# #T_2fb7f_row2_col4, #T_2fb7f_row3_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #edeff2;
#   color: #000000;
# }
# #T_2fb7f_row2_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #ebeef1;
#   color: #000000;
# }
# #T_2fb7f_row2_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #eceff1;
#   color: #000000;
# }
# #T_2fb7f_row2_col9, #T_2fb7f_row3_col9, #T_2fb7f_row5_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #13678a;
#   color: #f1f1f1;
# }
# #T_2fb7f_row3_col6 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #e4eaed;
#   color: #000000;
# }
# #T_2fb7f_row3_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #edf0f2;
#   color: #000000;
# }
# #T_2fb7f_row4_col3 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #BD2A2E 100.0%, transparent 100.0%);
# }
# #T_2fb7f_row4_col4 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_2fb7f_row4_col7 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #2c7796;
#   color: #f1f1f1;
# }
# #T_2fb7f_row4_col8 {
#   background-color: #101719;
#   color: #E0E0E0;
#   border: 1px solid #2F3D40;
#   text-align: center;
#   background-color: #f2efef;
#   color: #000000;
# }
# </style>
# <table id="T_2fb7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fb7f_level0_col0" class="col_heading level0 col0" >Coluna</th>
#       <th id="T_2fb7f_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_2fb7f_level0_col2" class="col_heading level0 col2" >Quantidade de Dados Não Vazios</th>
#       <th id="T_2fb7f_level0_col3" class="col_heading level0 col3" >Quantidade de Dados Vazios</th>
#       <th id="T_2fb7f_level0_col4" class="col_heading level0 col4" >Valores Únicos</th>
#       <th id="T_2fb7f_level0_col5" class="col_heading level0 col5" >Valor mais Frequente</th>
#       <th id="T_2fb7f_level0_col6" class="col_heading level0 col6" >Frequência</th>
#       <th id="T_2fb7f_level0_col7" class="col_heading level0 col7" >Porcentagem de Unicidade</th>
#       <th id="T_2fb7f_level0_col8" class="col_heading level0 col8" >Porcentagem de Valor Vazios (%)</th>
#       <th id="T_2fb7f_level0_col9" class="col_heading level0 col9" >Consumo de Memória - Total: 0.88 (MB)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fb7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fb7f_row0_col0" class="data row0 col0" >ID_CLIENTE</td>
#       <td id="T_2fb7f_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_2fb7f_row0_col2" class="data row0 col2" >12275</td>
#       <td id="T_2fb7f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2fb7f_row0_col4" class="data row0 col4" >976</td>
#       <td id="T_2fb7f_row0_col5" class="data row0 col5" >1156053485989336481</td>
#       <td id="T_2fb7f_row0_col6" class="data row0 col6" >213</td>
#       <td id="T_2fb7f_row0_col7" class="data row0 col7" >7.95</td>
#       <td id="T_2fb7f_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_2fb7f_row0_col9" class="data row0 col9" >0.093651</td>
#     </tr>
#     <tr>
#       <th id="T_2fb7f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fb7f_row1_col0" class="data row1 col0" >SAFRA_REF</td>
#       <td id="T_2fb7f_row1_col1" class="data row1 col1" >str</td>
#       <td id="T_2fb7f_row1_col2" class="data row1 col2" >12275</td>
#       <td id="T_2fb7f_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_2fb7f_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_2fb7f_row1_col5" class="data row1 col5" >2021-10</td>
#       <td id="T_2fb7f_row1_col6" class="data row1 col6" >2673</td>
#       <td id="T_2fb7f_row1_col7" class="data row1 col7" >0.04</td>
#       <td id="T_2fb7f_row1_col8" class="data row1 col8" >0.00</td>
#       <td id="T_2fb7f_row1_col9" class="data row1 col9" >0.175595</td>
#     </tr>
#     <tr>
#       <th id="T_2fb7f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2fb7f_row2_col0" class="data row2 col0" >DATA_EMISSAO_DOCUMENTO</td>
#       <td id="T_2fb7f_row2_col1" class="data row2 col1" >str</td>
#       <td id="T_2fb7f_row2_col2" class="data row2 col2" >12275</td>
#       <td id="T_2fb7f_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_2fb7f_row2_col4" class="data row2 col4" >150</td>
#       <td id="T_2fb7f_row2_col5" class="data row2 col5" >2021-11-04</td>
#       <td id="T_2fb7f_row2_col6" class="data row2 col6" >177</td>
#       <td id="T_2fb7f_row2_col7" class="data row2 col7" >1.22</td>
#       <td id="T_2fb7f_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_2fb7f_row2_col9" class="data row2 col9" >0.210714</td>
#     </tr>
#     <tr>
#       <th id="T_2fb7f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2fb7f_row3_col0" class="data row3 col0" >DATA_VENCIMENTO</td>
#       <td id="T_2fb7f_row3_col1" class="data row3 col1" >str</td>
#       <td id="T_2fb7f_row3_col2" class="data row3 col2" >12275</td>
#       <td id="T_2fb7f_row

# %% [markdown]
# Para que o modelo de Machine Learning possa ser aplicado corretamente, é essencial que a base de teste não contenha valores nulos ou vazios. Dessa forma, será realizada uma análise da coluna `VALOR_A_PAGAR` a fim de definir uma estratégia adequada para o preenchimento dos dados faltantes.
#
# Considerando a presença de possíveis outliers e a natureza assimétrica da variável, optou-se pela imputação dos valores ausentes utilizando a mediana, por ser uma medida mais robusta do que a média.

# %%
# Cálculo da mediana  
mediana_teste = df_teste['VALOR_A_PAGAR'].median()
df_teste['VALOR_A_PAGAR'] = df_teste['VALOR_A_PAGAR'].fillna(mediana_teste)

# Transformar colunas object para datetime
cols = ['DATA_EMISSAO_DOCUMENTO', 'DATA_VENCIMENTO']
df_teste[cols] = df_teste[cols].apply(pd.to_datetime)

# %% [markdown]
# Variáveis do tipo data, como dia/mês/ano, carregam informações temporais relevantes que não podem ser utilizadas diretamente pelos modelos de Machine Learning. Por esse motivo, é fundamental realizar um tratamento adequado desse tipo de dado, convertendo-o para um formato que permita a extração de conhecimento.
#
# A partir das datas, é possível criar novas features que capturam padrões temporais importantes, como ano, mês, dia, dia da semana ou períodos específicos, permitindo que o modelo identifique sazonalidades, tendências e comportamentos recorrentes ao longo do tempo.
#
# Esse processo de feature engineering contribui significativamente para o aumento do poder preditivo do modelo, pois transforma informações temporais brutas em variáveis numéricas mais interpretáveis e relevantes para a tarefa de aprendizado.

# %%
# Coluna Emissão Documentos
df_teste["Mes_Emissao_Documento"] = df_teste["DATA_EMISSAO_DOCUMENTO"].dt.month
df_teste["Dia_Emissao_Documento"] = df_teste["DATA_EMISSAO_DOCUMENTO"].dt.day

# Coluna Mês Vencimento 
df_teste["Mes_Vencimento"] = df_teste["DATA_VENCIMENTO"].dt.month
df_teste["Dia_Vencimento"] = df_teste["DATA_VENCIMENTO"].dt.day

display(df_teste)
# Out:
#                 ID_CLIENTE SAFRA_REF DATA_EMISSAO_DOCUMENTO DATA_VENCIMENTO  \
# 0      5058298901476893676   2021-07             2021-07-14      2021-08-04
# 1       274692171162531764   2021-07             2021-07-08      2021-08-23
# 2       274692171162531764   2021-07             2021-07-11      2021-08-25
# 3       274692171162531764   2021-07             2021-07-16      2021-08-30
# 4       465309249432033993   2021-07             2021-07-05      2021-07-30
# ...                    ...       ...                    ...             ...
# 12270   705648002974742140   2021-11             2021-11-25      2021-12-13
# 12271  4993499380140734678   2021-11             2021-11-25      2021-12-13
# 12272  4614484019183480654   2021-11             2021-11-26      2028-09-30
# 12273  1299146298565441811   2021-11             2021-11-26      2021-12-13
# 12274  4061297388883391410   2021-11             2021-11-28      2021-12-23
#
#        VALOR_A_PAGAR  TAXA  Mes_Emissao_Documento  Dia_Emissao_Documento  \
# 0           11204.75  4.99                      7                     14
# 1           60718.50  5.99                      7                      8
# 2           60718.50  5.99                      7                     11
# 3           62250.00  5.99                      7                     16
# 4           26593.95  6.99                      7                      5
# ...              ...   ...                    ...                    ...
# 12270       47010.00  6.99                     11                     25
# 12271      122875.35  8.99                     11                     25
# 12272      302200.00  5.99                     11                     26
# 12273      143791.85  5.99                     11                     26
# 12274       23724.10  4.99                     11                     28
#
#        Mes_Vencimento  Dia_Vencimento
# 0                   8               4
# 1                   8              23
# 2                   8              25
# 3                   8              30
# 4                   7              30
# ...               ...             ...
# 12270              12              13
# 12271              12              13
# 12272               9              30
# 12273              12              13
# 12274              12              23
#
# [12275 rows x 10 columns]

# %% [markdown]
# Quando estamos trabalhando em um projeto de Machine Learning é importante que os todos os dados sejam do tipo numérico, como construimos novas features com as colunas do tipo data, vamos exclui-las.

# %%
df_teste.to_parquet('docs/dataset_teste_limpo.parquet', engine='pyarrow')
display(df_teste)
# Out:
#                 ID_CLIENTE SAFRA_REF DATA_EMISSAO_DOCUMENTO DATA_VENCIMENTO  \
# 0      5058298901476893676   2021-07             2021-07-14      2021-08-04
# 1       274692171162531764   2021-07             2021-07-08      2021-08-23
# 2       274692171162531764   2021-07             2021-07-11      2021-08-25
# 3       274692171162531764   2021-07             2021-07-16      2021-08-30
# 4       465309249432033993   2021-07             2021-07-05      2021-07-30
# ...                    ...       ...                    ...             ...
# 12270   705648002974742140   2021-11             2021-11-25      2021-12-13
# 12271  4993499380140734678   2021-11             2021-11-25      2021-12-13
# 12272  4614484019183480654   2021-11             2021-11-26      2028-09-30
# 12273  1299146298565441811   2021-11             2021-11-26      2021-12-13
# 12274  4061297388883391410   2021-11             2021-11-28      2021-12-23
#
#        VALOR_A_PAGAR  TAXA  Mes_Emissao_Documento  Dia_Emissao_Documento  \
# 0           11204.75  4.99                      7                     14
# 1           60718.50  5.99                      7                      8
# 2           60718.50  5.99                      7                     11
# 3           62250.00  5.99                      7                     16
# 4           26593.95  6.99                      7                      5
# ...              ...   ...                    ...                    ...
# 12270       47010.00  6.99                     11                     25
# 12271      122875.35  8.99                     11                     25
# 12272      302200.00  5.99                     11                     26
# 12273      143791.85  5.99                     11                     26
# 12274       23724.10  4.99                     11                     28
#
#        Mes_Vencimento  Dia_Vencimento
# 0                   8               4
# 1                   8              23
# 2                   8              25
# 3                   8              30
# 4                   7              30
# ...               ...             ...
# 12270              12              13
# 12271              12              13
# 12272               9              30
# 12273              12              13
# 12274              12              23
#
# [12275 rows x 10 columns]

# %% [markdown]
# <div style="
#     background-color: #3D5A73;
#     color: white;
#     width: 700px;
#     height: 120px;                 /* define altura fixa */
#     margin: 20px auto;
#     border-radius: 15px;
#     display: flex;                 /* ativa flexbox */
#     align-items: center;           /* centraliza vertical */
#     justify-content: center;       /* centraliza horizontal */
# ">
#     <h1 style="margin: 0;">3. Análise Exploratória dos Dados</h1>
# </div>

# %% [markdown]
# A análise exploratória dos dados (Exploratory Data Analysis – EDA) é uma etapa fundamental em projetos de Data Science e Machine Learning, pois permite compreender a estrutura do dataset, identificar padrões, relações e anomalias, além de avaliar a qualidade dos dados. Por meio de estatísticas descritivas e visualizações, a EDA auxilia na detecção de outliers, vieses e possíveis problemas que podem impactar o desempenho dos modelos. Além disso, essa etapa fornece insights valiosos que orientam decisões sobre engenharia de features, seleção de variáveis e escolha de algoritmos, contribuindo para a construção de modelos mais robustos e confiáveis.

# %% [markdown]
# ## 3.1 Proporção entre Pessoa Física e Jurídica

# %%
df_flag = (df.FLAG_PF.value_counts(normalize=True)*100).to_frame().style.format("{:.2f}%").background_gradient(cmap='Blues')
df_flag
# Out:
# <style type="text/css">
# #T_28b20_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_28b20_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_28b20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28b20_level0_col0" class="col_heading level0 col0" >proportion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_PF</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28b20_level0_row0" class="row_heading level0 row0" >Juridico</th>
#       <td id="T_28b20_row0_col0" class="data row0 col0" >99.91%</td>
#     </tr>
#     <tr>
#       <th id="T_28b20_level0_row1" class="row_heading level0 row1" >Pessoa_Fisica</th>
#       <td id="T_28b20_row1_col0" class="data row1 col0" >0.09%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Quase 100% dos dados é composto por empresa do tipo PJ (Pessoa Jurídica). Isso nos revela um potência problema que pode afetar todo o dataset, o **Desbalanceamento de Dados**.
#
# Dados Desbalanceados podem ser definidos quando temos um pequena incidência de uma categoria dentro de um dataset (classe minoritária) em comparação com as demais categorias (classe majoritária). Na maioria dos casos, isso faz com que tenhamos muitas informações a respeito das categorias mais indidentes e menos das minoritárias.
#
# Quando formos construir o modelo de machine learning devemos tratar esse problema, pois se não lidados com isso de alguma maneira, dados desbalanceados podem acarretar em problemas na construção de modelos e geração de previsões.
#
# > Mas porque não tratar agora? Bom, nem sempre dados desbalanceados podem ser um problema, antes de montarmos qualquer modelo, explorar os dados e buscar insights lógicos a respeito dos dados que temos é sempre importante. Em muitos casos, o fato de estarmos trabalhando com dados desbalanceados durante a análise nem sempre trás prejuízos aos seus insights uma vez que algumas conclusões não necessitam de uma quantidade elevada (porém suficiente) de dados. Ademais, é de se perceber que, em muitos casos, descobrir o “porquê” do desbalanceamento pode trazer informações válidas para a resolução do problema.

# %% [markdown]
# ## 3.2 Proporção de Emails Utilizados
# Dando continuidade na exploração dos dados, vamos estudar a coluna de `DOMINIO_EMAIL`.
#
# É de extrema importância termos dados de contato dos clientes, pois assim, podemos manter uma relação de proximidade com o cliente, isso pode ser útil para oferecer serviços, cobrança, novas ofertas, etc.

# %%
func.plot_proportion_bar(df, column="DOMINIO_EMAIL")

# %% [markdown]
# O tamanho da empresa pode ser útil para ver a capacidade de produção que ela tem, se for grande, pode ter um elevado número de funcionários, gastos ou renda altos.

# %% [markdown]
# ## 3.3 Proporção do Porte e Segmento da Empresa

# %%
func.plot_proportion_bar(df, column="PORTE")

# %% [markdown]
# Já o segmento industrial refere-se a um setor específico dentro da economia, focado na transformação de matérias-primas em bens, utilizando máquinas e trabalho humano para criar produtos acabados ou intermediários.
#
# Nosso conjunto de dados é representado pelo segmento **indústria**, **comércio** e **serviço** abrange os três grandes setores da economia:
# - Indústria transforma matéria-prima em produtos (Setor Secundário);
# - Comércio vende esses produtos (parte do Setor Terciário); e
# - Serviços oferecem mão de obra e atividades especializadas, como saúde, educação, finanças (também Setor Terciário).

# %%
func.plot_proportion_bar(df, column = "SEGMENTO_INDUSTRIAL")

# %% [markdown]
# A distinção fundamental entre os setores reside no papel desempenhado por cada um: a indústria produz bens, o comércio intermedia sua comercialização, enquanto o setor de serviços comercializa capacidades ou atividades, e não produtos físicos.

# %% [markdown]
# ## 3.4 Relação entre Número de Funcionários e o Porte da Empresa
# O Número de Funcionários e o Porte da Empresa têm uma relação direta e crescente, pois o porte é, na prática, uma classificação baseada (total ou parcialmente) na quantidade de colaboradores.

# %%
# Relação entre número de funcionarios e o tamanho da empresa
df.groupby('PORTE')['NO_FUNCIONARIOS'].describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_864f1_row0_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_864f1_row0_col1, #T_864f1_row0_col3, #T_864f1_row0_col4, #T_864f1_row0_col5, #T_864f1_row0_col6, #T_864f1_row0_col7, #T_864f1_row1_col0, #T_864f1_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_864f1_row0_col2, #T_864f1_row1_col3, #T_864f1_row1_col7, #T_864f1_row2_col0, #T_864f1_row2_col1, #T_864f1_row2_col4, #T_864f1_row2_col5, #T_864f1_row2_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_864f1_row1_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_864f1_row1_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_864f1_row1_col4 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_864f1_row1_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_864f1_row1_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_864f1_row2_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_864f1_row2_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# </style>
# <table id="T_864f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_864f1_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_864f1_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_864f1_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_864f1_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_864f1_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_864f1_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_864f1_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_864f1_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PORTE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_864f1_level0_row0" class="row_heading level0 row0" >GRANDE</th>
#       <td id="T_864f1_row0_col0" class="data row0 col0" >28984.000000</td>
#       <td id="T_864f1_row0_col1" class="data row0 col1" >120.494141</td>
#       <td id="T_864f1_row0_col2" class="data row0 col2" >15.795825</td>
#       <td id="T_864f1_row0_col3" class="data row0 col3" >70.000000</td>
#       <td id="T_864f1_row0_col4" class="data row0 col4" >111.000000</td>
#       <td id="T_864f1_row0_col5" class="data row0 col5" >121.000000</td>
#       <td id="T_864f1_row0_col6" class="data row0 col6" >130.000000</td>
#       <td id="T_864f1_row0_col7" class="data row0 col7" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_864f1_level0_row1" class="row_heading level0 row1" >MEDIO</th>
#       <td id="T_864f1_row1_col0" class="data row1 col0" >32358.000000</td>
#       <td id="T_864f1_row1_col1" class="data row1 col1" >117.820208</td>
#       <td id="T_864f1_row1_col2" class="data row1 col2" >17.181092</td>
#       <td id="T_864f1_row1_col3" class="data row1 col3" >60.000000</td>
#       <td id="T_864f1_row1_col4" class="data row1 col4" >107.000000</td>
#       <td id="T_864f1_row1_col5" class="data row1 col5" >117.000000</td>
#       <td id="T_864f1_row1_col6" class="data row1 col6" >129.000000</td>
#       <td id="T_864f1_row1_col7" class="data row1 col7" >179.000000</td>
#     </tr>
#     <tr>
#       <th id="T_864f1_level0_row2" class="row_heading level0 row2" >PEQUENO</th>
#       <td id="T_864f1_row2_col0" class="data row2 col0" >15925.000000</td>
#       <td id="T_864f1_row2_col1" class="data row2 col1" >113.525570</td>
#       <td id="T_864f1_row2_col2" class="data row2 col2" >18.401174</td>
#       <td id="T_864f1_row2_col3" class="data row2 col3" >67.000000</td>
#       <td id="T_864f1_row2_col4" class="data row2 col4" >100.000000</td>
#       <td id="T_864f1_row2_col5" class="data row2 col5" >114.000000</td>
#       <td id="T_864f1_row2_col6" class="data row2 col6" >124.000000</td>
#       <td id="T_864f1_row2_col7" class="data row2 col7" >187.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
func.plot_mean_and_distribution(df, coluna1="PORTE", coluna2="NO_FUNCIONARIOS")

# %% [markdown]
# Quando analisamos esse tipo de dados, notamos uma média de funcionários crescente por porte, baixa sobreposição nos portes mais altos. O porte da empresa pode ser usado como proxy do tamano operacional, isso impacta diretamente análises de:
# - Churn de clientes B2B;
# - Capacidade de pagamento;
# - Risco de inadimplência;
# - Receita, custos e complexidade operacional
#
# Em resumo, o porte da empresa é uma categorização do seu tamanho, e o número de funcionários cresce de forma consistente conforme o porte aumenta, refletindo maior escala e complexidade operacional.

# %% [markdown]
# ## 3.5 Correlação entre Porte da Empresa e Segmento em ela Atua
# Existe uma correlação indireta e contextual entre o porte da empresa e o segmento em que ela atua. Embora uma empresa de qualquer porte possa atuar em qualquer segmento (indústria, comércio ou serviços), o segmento influencia os critérios de classificação e tende a favorecer determinados portes devido a características operacionais e de mercado.

# %%
func.plot_segmento_por_porte(df)

# %% [markdown]
# ## 3.6 Localização das Empresas
# Analisando os primeiros dois dígitos do CEP, podemos analisar a localização das empresas.

# %%
df['CEP_2_DIG'].value_counts().head(10).to_frame().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f93a8_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f93a8_row1_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_f93a8_row2_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_f93a8_row3_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_f93a8_row4_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_f93a8_row5_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_f93a8_row6_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_f93a8_row7_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f93a8_row8_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f93a8_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_f93a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f93a8_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CEP_2_DIG</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f93a8_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_f93a8_row0_col0" class="data row0 col0" >3884</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row1" class="row_heading level0 row1" >35</th>
#       <td id="T_f93a8_row1_col0" class="data row1 col0" >2845</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row2" class="row_heading level0 row2" >68</th>
#       <td id="T_f93a8_row2_col0" class="data row2 col0" >2603</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row3" class="row_heading level0 row3" >89</th>
#       <td id="T_f93a8_row3_col0" class="data row3 col0" >2588</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row4" class="row_heading level0 row4" >86</th>
#       <td id="T_f93a8_row4_col0" class="data row4 col0" >2135</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row5" class="row_heading level0 row5" >37</th>
#       <td id="T_f93a8_row5_col0" class="data row5 col0" >2107</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_f93a8_row6_col0" class="data row6 col0" >2076</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row7" class="row_heading level0 row7" >78</th>
#       <td id="T_f93a8_row7_col0" class="data row7 col0" >2006</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row8" class="row_heading level0 row8" >75</th>
#       <td id="T_f93a8_row8_col0" class="data row8 col0" >1773</td>
#     </tr>
#     <tr>
#       <th id="T_f93a8_level0_row9" class="row_heading level0 row9" >38</th>
#       <td id="T_f93a8_row9_col0" class="data row9 col0" >1655</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# De acordo com site dos correios, podemos obter informações sobre como o CEP funciona e o que os digitos pode nos dizer.
# Cada número de CEP corrensponde a uma Região, Sub-região, Setor, Subsetor, Divisor de Subsetor e Identificadores de Distribuição.
#
# ![alt text](img/cep_correios.png)
#
# O Brasil foi divido em dez regiões postais, indo do **0 ao 9**, o que define o primeiro número do CEP. A distribuição foi feita no sentido anti-horário, a partir do estado de São Paulo.
# - **Região 0 :** grande São Paulo;
# - **Região 1:** interior de São Paulo;
# - **Região 2:** Rio de Janeiro e Espírito Santo;
# - **Região 3:** Minas Gerais;
# - **Região 4:** Bahia e Sergipe;
# - **Região 5:** Pernambuco, Alagoas, Paraíba e Rio Grande do Norte;
# - **Região 6:** Ceará, Piauí, Maranhão, Pará, Roraima, Amapá, Acre e Amazonas;
# - **Região 7:** Distrito Federal, Goiás, Rondônia, Tocantins, Mato Grosso e Mato Grosso do Sul;
# - **Região 8:** Paraná e Santa Catarina;
# - **Região 9:** Rio Grande do Sul.
#
# Com base nessa informação podemos ver que o top 10 localidades das empresas são:
# - **1** - Interior de São Paulo;
# - **2** - Minas Gerais;
# - **3** - Ceará, Piauí, Maranhão, Pará, Roraima, Amapá, Acre e Amazonas;
# - **4 e 5** - Paraná e Santa Catarina;
# - **6** - Minas Gerais;
# - **7** - Interior de São Paulo
# - **8 e 9** - Distrito Federal, Goiás, Rondônia, Tocantins, Mato Grosso e Mato Grosso do Sul;
# - **10** - Minas Gerais.

# %% [markdown]
# <div style="
#     background-color: #3D5A73;
#     color: white;
#     width: 800px;
#     height: 120px;                 /* define altura fixa */
#     margin: 20px auto;
#     border-radius: 15px;
#     display: flex;                 /* ativa flexbox */
#     align-items: center;           /* centraliza vertical */
#     justify-content: center;       /* centraliza horizontal */
# ">
#     <h1 style="margin: 0;">4. Visualização da Variável Target (Churn)</h1>
# </div>

# %% [markdown]
# A maioria dos algoritmos de Machine Learning (regressão, árvores, redes neurais, SVM etc.) aprende padrões a partir de operações matemáticas como soma, multiplicação, distância e ordenação. Uma data no formato `dd/mm/aaaa` é, na prática, uma string ou um objeto temporal, e não um valor numérico com significado matemático direto para o modelo. Assim, Modelos de Machine Learning não lidam diretamente com datas porque elas não possuem significado matemático imediato. Para que a informação temporal seja aproveitada, é necessário transformá-la em variáveis numéricas que representem padrões relevantes do tempo.

# %%
# Transformar colunas object para datetime
cols = ['DATA_EMISSAO_DOCUMENTO', 'DATA_PAGAMENTO', 'DATA_VENCIMENTO']
df[cols] = df[cols].apply(pd.to_datetime)

# %% [markdown]
# O objetivo deste projeto é desenvolver um modelo de Machine Learning capaz de prever a probabilidade de inadimplência de clientes de uma instituição financeira.
#
# Neste contexto, considera-se cliente inadimplente aquele que realiza o **pagamento com 5 dias ou mais de atraso em relação à data de vencimento**.
#
# Para viabilizar essa previsão, será necessário criar a variável alvo, calculada a partir da diferença, em dias, entre a data de pagamento e a data de vencimento, permitindo classificar cada cliente conforme o critério de inadimplência definido.

# %%
# Cálculo da Inadimplência
df['Churned'] = np.where(((df['DATA_PAGAMENTO'] - df['DATA_VENCIMENTO']).dt.days) >= 5, 1, 0)

# %%
func.plot_proportion_bar(df, column = "Churned")

# %% [markdown]
# Aqui temos um caso clássico de desbalanceamos de dados, em problemas de **classificação**, dizemos que um conjunto de dados é desbalanceado quando uma ou mais classes possuem uma quantidade significativamente menor de observações em relação às demais. Um exemplo comum ocorre em modelos de churn, fraude ou detecção de falhas, nos quais a classe de interesse (como clientes que cancelam o serviço) representa uma pequena parcela do total de registros.
#
# Em resumo, dados desbalanceados exigem cuidados específicos ao longo de todo o processo de modelagem. Ignorar esse aspecto pode levar a conclusões equivocadas e modelos pouco eficazes na prática. Ao combinar técnicas de reamostragem, escolha adequada de métricas e ajustes no processo de decisão do modelo, é possível construir soluções mais robustas, interpretáveis e alinhadas aos objetivos do problema real.

# %%
func.plot_pag(df)

# %% [markdown]
# Neste gráfico vemos a distrubuição das datas dos dias de vencimento do nosso dataset, é possível observar que no dia 5 do mês é onde ocorre a maior quantidade de pagamento. A segunda feira é o dia com maior frequência de pagamento e por fim temos a média da diferença entre o dia de pagamento e vencimento, onde valores positivos indicam atraso, valores zero indicam pagamento em dia e valores negativos indicam pagamento antecipado.

# %%
func.plot_churned(df)

# %% [markdown]
# Neste outro conjunto de gráficos, quando analisamos a quantidade de churned por segmento industrial vemos que o setor de Serviço é o que apresenta maior número de inadimplência em comparação ao Comércio e Indústrial, essa característica pode ser consequência desse setor representar uma grande parcela dos dados do nosso dataset. Já quando observamos a taxa temos que empresas com taxa de 5.99 são maioria e tem maior churned em relação as demais taxas e o Porte da empresa que Médio se destaca por seus números expressivos.

# %% [markdown]
# <div style="
#     background-color: #3D5A73;
#     color: white;
#     width: 800px;
#     height: 120px;                 /* define altura fixa */
#     margin: 20px auto;
#     border-radius: 15px;
#     display: flex;                 /* ativa flexbox */
#     align-items: center;           /* centraliza vertical */
#     justify-content: center;       /* centraliza horizontal */
# ">
#     <h1 style="margin: 0;">Conclusão</h1>
# </div>

# %% [markdown]
# Nesta primeira etapa do estudo de caso, o foco foi compreender e preparar o dataset para as fases posteriores de modelagem. Foram aplicadas estratégias de tratamento de dados ausentes, utilizando imputação por média, mediana e abordagens baseadas em relações entre variáveis (groupby), com o objetivo de preservar a consistência e a qualidade das informações.
#
# Além disso, foi realizada uma análise exploratória dos dados, incluindo a descrição das features, visualizações gráficas e investigação das relações entre variáveis. Essa etapa permitiu uma melhor compreensão da estrutura do dataset e do comportamento dos dados.
#
# Por fim, a variável target, a inadimplência, foi analisada em profundidade, buscando identificar padrões, tendências e possíveis correlações com outras variáveis. Os insights obtidos fornecem uma base sólida para a próxima fase do projeto, que consiste na construção de modelos preditivos capazes de estimar o risco de inadimplência.
